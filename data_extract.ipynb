# %%
import pandas as pd
import re
from gtfparse import read_gtf
import polars as pl

# %% [markdown]
# # Functions

# %%
def read_file_and_modify(csv_file, treatment = ''):
    df = pd.read_csv(csv_file)
    if treatment != '':
        df['Treatment'] = treatment

    df['Enhancer'] = df['Enhancer'].str.replace(r'(+)', '')
    return df

# %% [markdown]
# # EDA

# %%
# Read the files
e20_df = read_file_and_modify('base_data/EnhancerGene20E_df_clean_09_09.csv', '20E')

con_df = read_file_and_modify('base_data/EnhancerGeneCon_df_clean_09_09.csv','Control')

imd_df = read_file_and_modify('base_data/EnhancerGeneHKSM_df_clean_09_09.csv', 'IMD')

combined_df = pd.concat([e20_df, con_df, imd_df])

all_df = read_file_and_modify('base_data/EG_all_clean_09_05.csv')
all_df['Treatment'] = all_df['Treatment'].replace({'HKSM':'IMD'})

tpm_counts = pd.read_csv('base_data/Allsamples_tpm.csv')

# %%
print(combined_df.shape)
combined_df.head()
# Out:
# (39130, 10)
#                Enhancer        Genes  Cells_20EvsCTRL.table.logFC  \
# 0  2R:16125955-16128021  FBgn0034075                    -0.487171
# 1  2R:16125955-16128021  FBgn0034076                     0.511375
# 2  2R:16125955-16128021  FBgn0010052                          NaN
# 3  2R:16125955-16128021  FBgn0050095                          NaN
# 4  2R:16125955-16128021  FBgn0001124                    -1.570842
#
#    coSTARR LogFC 20EvsControl Immune Process Time_cluster Treatment  \
# 0                   -0.065139            NaN          NaN       20E
# 1                         NaN            NaN          NaN       20E
# 2                   -3.331694            NaN      late_C1       20E
# 3                         NaN            NaN          NaN       20E
# 4                   -0.816459            NaN      late_C1       20E
#
#    Control_ave  2021 LogFC IMDvsCTRL  coSTARR LogFC HKSMvs20E
# 0          NaN                   NaN                      NaN
# 1          NaN                   NaN                      NaN
# 2          NaN                   NaN                      NaN
# 3          NaN                   NaN                      NaN
# 4          NaN                   NaN                      NaN

# %%
all_df.head()
# Out:
#                Enhancer                                              Genes  \
# 0    2R:1097242-1098153                                        FBgn0003256
# 1      2L:517706-518455                                        FBgn0003963
# 2      2L:521029-521849                                        FBgn0003963
# 3      2L:524444-525150                                        FBgn0003963
# 4  2L:19537144-19537644  FBgn0032798;FBgn0032799;FBgn0041180;FBgn003280...
#
#                                 2021 LogFC IMDvsCTRL  \
# 0                                        0.263686928
# 1                                        0.285124923
# 2                                        0.285124923
# 3                                        0.285124923
# 4  -0.8434705509999999;1.341826983;1.800378571;0....
#
#                              coSTARR LogFC HKSMvs20E  \
# 0                                       -0.038253087
# 1                                       -0.387774183
# 2                                       -0.387774183
# 3                                       -0.387774183
# 4  0.083930202;0.141035456;0.085920669;-0.2594895...
#
#                          Immune Process Time_cluster  new_act_score  Length  \
# 0                          Wound repair            0       2182.190     912
# 1                        Toll; Cellular            0        817.905     750
# 2                        Toll; Cellular            0        547.332     821
# 3                        Toll; Cellular            0       1383.430     707
# 4  Toll; Anti-viral;0;Humoral; Cellular   0;early_C2        905.856     501
#
#            FlybaseID Lem_function                      Type_function  ...  \
# 0                              []                                  0  ...
# 1                 ['FBgn0003963']                      Hematopoeisis  ...
# 2                 ['FBgn0003963']                      Hematopoeisis  ...
# 3                 ['FBgn0003963']                      Hematopoeisis  ...
# 4  ['FBgn0003231', 'FBgn0041180']  Phagocytosis, Signaling/Antiviral  ...
#
#   xrp1_3 TBS_10-3  Treatment  FB_Gene  Control_ave  \
# 0      1       29        IMD      NaN          NaN
# 1      3       27        IMD      NaN          NaN
# 2      4       16        IMD      NaN          NaN
# 3      1       20        IMD      NaN          NaN
# 4      1       10        IMD      NaN          NaN
#
#    Cells_20EvsCTRL.table.logFC  coSTARR LogFC 20EvsControl  HKSM_ATAC  \
# 0                          NaN                         NaN        yes
# 1                          NaN                         NaN        NaN
# 2                          NaN                         NaN        NaN
# 3                          NaN                         NaN        yes
# 4                          NaN                         NaN        NaN
#
#    Con_ATAC  Accessibility
# 0       yes    Always open
# 1       NaN  Always closed
# 2       NaN  Always closed
# 3       yes    Always open
# 4       NaN  Always closed
#
# [5 rows x 34 columns]

# %%
print('e20_df.shape',e20_df.shape, '\ncon_df.shape', con_df.shape,'\nimd_df.shape', imd_df.shape)
print()
print("Unique Enhancers in 20E, IMD and Control combined:", len(combined_df['Enhancer'].unique()))
print("Unique Enhancers on collapsed file:", len(all_df['Enhancer'].unique()))
# Out:
# e20_df.shape (14154, 7)
# con_df.shape (11272, 6)
# imd_df.shape (13704, 7)
#
# Unique Enhancers in 20E, IMD and Control combined: 8204
# Unique Enhancers on collapsed file: 8204

# %% [markdown]
# # Enhancer Table

# %%
# Extract the 'Enhancer' column
enhancer = combined_df['Enhancer']

# Parse chromosome, start, and end from the Enhancer string
combined_df['Chromosome'] = enhancer.apply(lambda x: x.split(':')[0])
combined_df['Start'] = enhancer.apply(lambda x: int(re.search(r':(\d+)-', x).group(1)))
combined_df['End'] = enhancer.apply(lambda x: int(re.search(r'-(\d+)', x).group(1)))
combined_df['Length'] = abs(combined_df['End'] - combined_df['Start'])

# %%
# Display the updated DataFrame and store it to csv
combined_df.reset_index(drop = True, inplace = True)
tf_col = ['crp_3', 'EcR_usp_3', 'Eip74EF_3', 'gcm_3', 'Hnf4_3',
       'kay_Jra_3', 'Rel_3', 'slp2_fork_3', 'SREBP_3', 'srp_SANGER_3', 'Trl_3', 'XBP1_3', 'xrp1_3']
all_df['TF_counts'] = all_df[tf_col].apply(lambda row: '; '.
                                             join([f'{col}: {int(row[col])}' for col in tf_col if row[col] > 0]),
                                             axis = 1)

# %%
enhancer_df = pd.merge(
    combined_df[['Enhancer','Chromosome','Start','End','Length','Treatment']],
    all_df[['Enhancer','TF_counts','TBS_10-3']],
    on='Enhancer',
    how='left'
).drop_duplicates(ignore_index=True)

enhancer_df = enhancer_df.rename(columns={
    'TBS_10-3':'TBS'
})

enhancer_df.to_csv('processed_data/enhancer.csv', index=False)

# %% [markdown]
# # Genes Table

# %%
# gene csv
gene_df = combined_df[['Genes','Immune Process','Time_cluster']]
gene_df.reset_index(drop = True, inplace = True)
gene_df.rename(columns = {'Genes':'gene_id'},inplace = True)
gene_df
# Out:
# /var/folders/mh/p8rsw7z90bv6kv8r8qnf4tnr0000gn/T/ipykernel_20199/3327782363.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gene_df.rename(columns = {'Genes':'gene_id'},inplace = True)
#            gene_id Immune Process Time_cluster
# 0      FBgn0034075            NaN          NaN
# 1      FBgn0034076            NaN          NaN
# 2      FBgn0010052            NaN      late_C1
# 3      FBgn0050095            NaN          NaN
# 4      FBgn0001124            NaN      late_C1
# ...            ...            ...          ...
# 39125  FBgn0267432            NaN          NaN
# 39126  FBgn0001313            NaN          NaN
# 39127          NaN            NaN          NaN
# 39128          NaN            NaN          NaN
# 39129          NaN            NaN          NaN
#
# [39130 rows x 3 columns]

# %%
# Make a unique list of genes
unique_genes = gene_df['gene_id'].dropna().unique()
unique_genes = unique_genes.tolist()
len(unique_genes)
# Out:
# 10411

# %%
# Read gtf file
gtf_file = read_gtf('base_data/Drosophila_melanogaster.BDGP6.54.115.gtf')
print(gtf_file.shape)
gtf_file.head()
# Out:
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_name', 'gene_source', 'gene_biotype', 'transcript_id', 'transcript_source', 'transcript_biotype', 'tag', 'exon_number', 'exon_id', 'transcript_name', 'protein_id']
# (567804, 20)
# shape: (5, 20)
# ┌─────────┬─────────┬────────────┬──────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ seqname ┆ source  ┆ feature    ┆ start    ┆ … ┆ exon_numbe ┆ exon_id    ┆ transcript ┆ protein_i │
# │ ---     ┆ ---     ┆ ---        ┆ ---      ┆   ┆ r          ┆ ---        ┆ _name      ┆ d         │
# │ cat     ┆ cat     ┆ cat        ┆ i64      ┆   ┆ ---        ┆ str        ┆ ---        ┆ ---       │
# │         ┆         ┆            ┆          ┆   ┆ str        ┆            ┆ str        ┆ str       │
# ╞═════════╪═════════╪════════════╪══════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 3R      ┆ FlyBase ┆ gene       ┆ 10964778 ┆ … ┆            ┆            ┆            ┆           │
# │ 3R      ┆ FlyBase ┆ transcript ┆ 10964778 ┆ … ┆            ┆            ┆            ┆           │
# │ 3R      ┆ FlyBase ┆ exon       ┆ 10964778 ┆ … ┆ 1          ┆ FBti006091 ┆            ┆           │
# │         ┆         ┆            ┆          ┆   ┆            ┆ 1-RA-E1    ┆            ┆           │
# │ 3R      ┆ FlyBase ┆ gene       ┆ 13944654 ┆ … ┆            ┆            ┆            ┆           │
# │ 3R      ┆ FlyBase ┆ transcript ┆ 13944654 ┆ … ┆            ┆            ┆ Art6-RA    ┆           │
# └─────────┴─────────┴────────────┴──────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
gtf_genes = gtf_file.filter(pl.col("feature") == "gene")
gtf_genes.head(n = 10)
# Out:
# shape: (10, 20)
# ┌─────────┬─────────┬─────────┬──────────┬───┬─────────────┬─────────┬────────────────┬────────────┐
# │ seqname ┆ source  ┆ feature ┆ start    ┆ … ┆ exon_number ┆ exon_id ┆ transcript_nam ┆ protein_id │
# │ ---     ┆ ---     ┆ ---     ┆ ---      ┆   ┆ ---         ┆ ---     ┆ e              ┆ ---        │
# │ cat     ┆ cat     ┆ cat     ┆ i64      ┆   ┆ str         ┆ str     ┆ ---            ┆ str        │
# │         ┆         ┆         ┆          ┆   ┆             ┆         ┆ str            ┆            │
# ╞═════════╪═════════╪═════════╪══════════╪═══╪═════════════╪═════════╪════════════════╪════════════╡
# │ 3R      ┆ FlyBase ┆ gene    ┆ 10964778 ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 13944654 ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 8359958  ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 18330932 ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 17703695 ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 5862865  ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 12452464 ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 9483378  ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 4639789  ┆ … ┆             ┆         ┆                ┆            │
# │ 3R      ┆ FlyBase ┆ gene    ┆ 4605495  ┆ … ┆             ┆         ┆                ┆            │
# └─────────┴─────────┴─────────┴──────────┴───┴─────────────┴─────────┴────────────────┴────────────┘

# %%
filtered_genes = gtf_genes.filter(pl.col("gene_id").is_in(unique_genes))

# %%
result_df = pd.merge(
    filtered_genes[['gene_id','seqname','start','end','gene_name']].to_pandas(),
    gene_df[['gene_id','Immune Process', 'Time_cluster']],
    on='gene_id',
    how='left')

result_df.columns = ['GeneID','Chromosome', 'Start', 'End', 'GeneName','Immune Process','Time_cluster']
result_df['Length'] = abs(result_df['End'] - result_df['Start'])

result_df.drop_duplicates(ignore_index = True,inplace = True)
result_df.reset_index(drop=True, inplace=True)
result_df
# Out:
#             GeneID Chromosome     Start       End        GeneName  \
# 0      FBgn0038189         3R  13944654  13945812            Art6
# 1      FBgn0037583         3R   8359958   8362554          Veneno
# 2      FBgn0267702         3R  17703695  17705581  lncRNA:CR46035
# 3      FBgn0083949         3R   5862865   5959555        side-III
# 4      FBgn0038054         3R  12452464  12453196          CG5509
# ...            ...        ...       ...       ...             ...
# 10278  FBgn0267880          Y   3113685   3114094         CR46168
# 10279  FBgn0039925          4   1147466   1169239           Kif3C
# 10280  FBgn0039924          4   1192419   1196848           PIP4K
# 10281  FBgn0250819          4   1185768   1192985         CG33521
# 10282  FBgn0002521          4   1172469   1181628             pho
#
#       Immune Process Time_cluster  Length
# 0                NaN          NaN    1158
# 1                NaN          NaN    2596
# 2                NaN          NaN    1886
# 3                NaN          NaN   96690
# 4                NaN          NaN     732
# ...              ...          ...     ...
# 10278            NaN          NaN     409
# 10279            NaN          NaN   21773
# 10280            NaN          NaN    4429
# 10281            NaN          NaN    7217
# 10282            NaN          NaN    9159
#
# [10283 rows x 8 columns]

# %%
# Convert unique genes list to a set
unique_genes_set = set(unique_genes)

# Convert filtered gene_ids (Polars) to a set
filtered_gene_ids_set = set(filtered_genes["gene_id"].to_list())

# Find unmapped genes
unmapped_genes = unique_genes_set - filtered_gene_ids_set

print(f"Number of unmapped genes: {len(unmapped_genes)}")
unmapped_genes
# Out:
# Number of unmapped genes: 129
# {'FBgn0000054',
#  'FBgn0000409',
#  'FBgn0000497',
#  'FBgn0000556',
#  'FBgn0001974',
#  'FBgn0001981',
#  'FBgn0002607',
#  'FBgn0003328',
#  'FBgn0003732',
#  'FBgn0003887',
#  'FBgn0003888',
#  'FBgn0003926',
#  'FBgn0004009',
#  'FBgn0004364',
#  'FBgn0005592',
#  'FBgn0010575',
#  'FBgn0011241',
#  'FBgn0011655',
#  'FBgn0014002',
#  'FBgn0015393',
#  'FBgn0016700',
#  'FBgn0019643',
#  'FBgn0019886',
#  'FBgn0019947',
#  'FBgn0021818',
#  'FBgn0022772',
#  'FBgn0024332',
#  'FBgn0025286',
#  'FBgn0025683',
#  'FBgn0025687',
#  'FBgn0027585',
#  'FBgn0028336',
#  'FBgn0028519',
#  'FBgn0028665',
#  'FBgn0029082',
#  'FBgn0029173',
#  'FBgn0029656',
#  'FBgn0029707',
#  'FBgn0029899',
#  'FBgn0030170',
#  'FBgn0030294',
#  'FBgn0031821',
#  'FBgn0031842',
#  'FBgn0032276',
#  'FBgn0032679',
#  'FBgn0032906',
#  'FBgn0032915',
#  'FBgn0033059',
#  'FBgn0033359',
#  'FBgn0033465',
#  'FBgn0033981',
#  'FBgn0034496',
#  'FBgn0034967',
#  'FBgn0035707',
#  'FBgn0035987',
#  'FBgn0036169',
#  'FBgn0036660',
#  'FBgn0037010',
#  'FBgn0037417',
#  'FBgn0037636',
#  'FBgn0038035',
#  'FBgn0038052',
#  'FBgn0038220',
#  'FBgn0038341',
#  'FBgn0038893',
#  'FBgn0039177',
#  'FBgn0039255',
#  'FBgn0039632',
#  'FBgn0039959',
#  'FBgn0040001',
#  'FBgn0040813',
#  'FBgn0042174',
#  'FBgn0050007',
#  'FBgn0050118',
#  'FBgn0050456',
#  'FBgn0050497',
#  'FBgn0051320',
#  'FBgn0051728',
#  'FBgn0058178',
#  'FBgn0082953',
#  'FBgn0082990',
#  'FBgn0082993',
#  'FBgn0086026',
#  'FBgn0086029',
#  'FBgn0086031',
#  'FBgn0086032',
#  'FBgn0086036',
#  'FBgn0086037',
#  'FBgn0086038',
#  'FBgn0086043',
#  'FBgn0086044',
#  'FBgn0086045',
#  'FBgn0086046',
#  'FBgn0086052',
#  'FBgn0086058',
#  'FBgn0086060',
#  'FBgn0086077',
#  'FBgn0086080',
#  'FBgn0086081',
#  'FBgn0086082',
#  'FBgn0086901',
#  'FBgn0250876',
#  'FBgn0259234',
#  'FBgn0259247',
#  'FBgn0259697',
#  'FBgn0259822',
#  'FBgn0260441',
#  'FBgn0261241',
#  'FBgn0261606',
#  'FBgn0261699',
#  'FBgn0262095',
#  'FBgn0262262',
#  'FBgn0262394',
#  'FBgn0262423',
#  'FBgn0262511',
#  'FBgn0262735',
#  'FBgn0262742',
#  'FBgn0262818',
#  'FBgn0263039',
#  'FBgn0263118',
#  'FBgn0265434',
#  'FBgn0265988',
#  'FBgn0266421',
#  'FBgn0266526',
#  'FBgn0267040',
#  'FBgn0267117',
#  'FBgn0267727',
#  'FBgn0267911',
#  'FBgn0283462'}

# %%
gtf_file
# Out:
# shape: (567_804, 20)
# ┌────────────┬─────────┬────────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ seqname    ┆ source  ┆ feature    ┆ start    ┆ … ┆ exon_numb ┆ exon_id   ┆ transcrip ┆ protein_i │
# │ ---        ┆ ---     ┆ ---        ┆ ---      ┆   ┆ er        ┆ ---       ┆ t_name    ┆ d         │
# │ cat        ┆ cat     ┆ cat        ┆ i64      ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │            ┆         ┆            ┆          ┆   ┆ str       ┆           ┆ str       ┆ str       │
# ╞════════════╪═════════╪════════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 3R         ┆ FlyBase ┆ gene       ┆ 10964778 ┆ … ┆           ┆           ┆           ┆           │
# │ 3R         ┆ FlyBase ┆ transcript ┆ 10964778 ┆ … ┆           ┆           ┆           ┆           │
# │ 3R         ┆ FlyBase ┆ exon       ┆ 10964778 ┆ … ┆ 1         ┆ FBti00609 ┆           ┆           │
# │            ┆         ┆            ┆          ┆   ┆           ┆ 11-RA-E1  ┆           ┆           │
# │ 3R         ┆ FlyBase ┆ gene       ┆ 13944654 ┆ … ┆           ┆           ┆           ┆           │
# │ 3R         ┆ FlyBase ┆ transcript ┆ 13944654 ┆ … ┆           ┆           ┆ Art6-RA   ┆           │
# │ …          ┆ …       ┆ …          ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2110000222 ┆ FlyBase ┆ transcript ┆ 14       ┆ … ┆           ┆           ┆ Su(Ste):C ┆           │
# │ 79165      ┆         ┆            ┆          ┆   ┆           ┆           ┆ R42439-RA ┆           │
# │ 2110000222 ┆ FlyBase ┆ exon       ┆ 14       ┆ … ┆ 1         ┆ FBtr03001 ┆ Su(Ste):C ┆           │
# │ 79165      ┆         ┆            ┆          ┆   ┆           ┆ 67-E1     ┆ R42439-RA ┆           │
# │ 2110000222 ┆ FlyBase ┆ gene       ┆ 180      ┆ … ┆           ┆           ┆           ┆           │
# │ 79264      ┆         ┆            ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 2110000222 ┆ FlyBase ┆ transcript ┆ 180      ┆ … ┆           ┆           ┆ lncRNA:CR ┆           │
# │ 79264      ┆         ┆            ┆          ┆   ┆           ┆           ┆ 40719-RB  ┆           │
# │ 2110000222 ┆ FlyBase ┆ exon       ┆ 180      ┆ … ┆ 1         ┆ FBtr03041 ┆ lncRNA:CR ┆           │
# │ 79264      ┆         ┆            ┆          ┆   ┆           ┆ 47-E1     ┆ 40719-RB  ┆           │
# └────────────┴─────────┴────────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
unmapped_feature_mapping = gtf_file.filter(pl.col("gene_id").is_in(unmapped_genes))
unmapped_feature_mapping

# Unmapped genes do not map to anything, but added to the final genes.csv
# Out:
# shape: (0, 20)
# ┌─────────┬────────┬─────────┬───────┬───┬─────────────┬─────────┬─────────────────┬────────────┐
# │ seqname ┆ source ┆ feature ┆ start ┆ … ┆ exon_number ┆ exon_id ┆ transcript_name ┆ protein_id │
# │ ---     ┆ ---    ┆ ---     ┆ ---   ┆   ┆ ---         ┆ ---     ┆ ---             ┆ ---        │
# │ cat     ┆ cat    ┆ cat     ┆ i64   ┆   ┆ str         ┆ str     ┆ str             ┆ str        │
# ╞═════════╪════════╪═════════╪═══════╪═══╪═════════════╪═════════╪═════════════════╪════════════╡
# └─────────┴────────┴─────────┴───────┴───┴─────────────┴─────────┴─────────────────┴────────────┘

# %%
unmapped_genes = pd.DataFrame(unmapped_genes,columns=['gene_id']).rename(columns={'gene_id':'GeneID'})
genes = pd.concat([result_df,unmapped_genes])
print(len(unique_genes),len(genes))
# Out:
# 10411 10412

# %% [markdown]
# ## TPM

# %% [markdown]
# ~~S1: Control, Replicate 1~~ - Outlier
#
# S2: 20E, Replicate 1
#
# S3: IMD (HKSM), Replicate 1
#
# S4: Control, Replicate 2
#
# S5: 20E, Replicate 2
#
# S6: IMD (HKSM), Replicate 2
#
# S7: Control, Replicate 3
#
# S8: 20E, Replicate 3
#
# S9: IMD (HKSM), Replicate 3

# %%
# Control Average
tpm_counts['tpm_ctrl'] = (tpm_counts['S4_counts'] + tpm_counts['S7_counts'])/2

# 20E average
tpm_counts['tpm_20e'] = (tpm_counts['S2_counts'] + tpm_counts['S5_counts'] + tpm_counts['S8_counts'])/3

# IMD average
tpm_counts['tpm_imd'] = (tpm_counts['S3_counts'] + tpm_counts['S6_counts'] + tpm_counts['S9_counts'])/3
tpm_counts
# Out:
#            FB_Gene  S1_counts   S2_counts   S3_counts  S4_counts  S5_counts  \
# 0      FBgn0031081   3.557237    0.010032    0.027937   0.000000   0.021195
# 1      FBgn0052826   0.000000    0.000000    0.000000   0.000000   0.000000
# 2      FBgn0031085   5.224219    0.000000    0.110539   0.000000   0.000000
# 3      FBgn0062565  59.890682  113.678741  106.025847  50.292973  84.532776
# 4      FBgn0031088   1.449757    0.015499    0.014386   0.000000   0.000000
# ...            ...        ...         ...         ...        ...        ...
# 17601  FBgn0031288   0.000000    0.123413    0.190928   0.349307   0.130369
# 17602  FBgn0031289   0.000000    0.082136    0.076242   0.697436   0.260297
# 17603  FBgn0002936   0.000000    0.000000    0.000000   0.000000   0.000000
# 17604  FBgn0002563   0.173298    0.000000    0.016433   0.125267   0.000000
# 17605  FBgn0046113   0.070483    0.000000    0.000000   0.000000   0.000000
#
#        S6_counts  S7_counts  S8_counts  S9_counts   tpm_ctrl    tpm_20e  \
# 0       0.000000   0.000000   0.136597   0.000000   0.000000   0.055941
# 1       0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2       0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 3      66.951918  36.736645  72.550286  52.186025  43.514809  90.253934
# 4       0.000000   0.000000   0.000000   0.000000   0.000000   0.005166
# ...          ...        ...        ...        ...        ...        ...
# 17601   0.218569   0.900850   0.373418   0.160965   0.625079   0.209066
# 17602   0.130920   0.449665   0.310656   0.000000   0.573550   0.217697
# 17603   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 17604   0.000000   0.048459   0.000000   0.000000   0.086863   0.000000
# 17605   0.017215   0.000000   0.000000   0.000000   0.000000   0.000000
#
#          tpm_imd
# 0       0.009312
# 1       0.000000
# 2       0.036846
# 3      75.054597
# 4       0.004795
# ...          ...
# 17601   0.190154
# 17602   0.069054
# 17603   0.000000
# 17604   0.005478
# 17605   0.005738
#
# [17606 rows x 13 columns]

# %%
genes
# Out:
#           GeneID Chromosome       Start         End        GeneName  \
# 0    FBgn0038189         3R  13944654.0  13945812.0            Art6
# 1    FBgn0037583         3R   8359958.0   8362554.0          Veneno
# 2    FBgn0267702         3R  17703695.0  17705581.0  lncRNA:CR46035
# 3    FBgn0083949         3R   5862865.0   5959555.0        side-III
# 4    FBgn0038054         3R  12452464.0  12453196.0          CG5509
# ..           ...        ...         ...         ...             ...
# 124  FBgn0036169        NaN         NaN         NaN             NaN
# 125  FBgn0086037        NaN         NaN         NaN             NaN
# 126  FBgn0086052        NaN         NaN         NaN             NaN
# 127  FBgn0025687        NaN         NaN         NaN             NaN
# 128  FBgn0267911        NaN         NaN         NaN             NaN
#
#     Immune Process Time_cluster   Length
# 0              NaN          NaN   1158.0
# 1              NaN          NaN   2596.0
# 2              NaN          NaN   1886.0
# 3              NaN          NaN  96690.0
# 4              NaN          NaN    732.0
# ..             ...          ...      ...
# 124            NaN          NaN      NaN
# 125            NaN          NaN      NaN
# 126            NaN          NaN      NaN
# 127            NaN          NaN      NaN
# 128            NaN          NaN      NaN
#
# [10412 rows x 8 columns]

# %%
genes = pd.merge(genes,tpm_counts[['FB_Gene','tpm_ctrl','tpm_20e','tpm_imd']],left_on='GeneID',right_on='FB_Gene',how='left')
genes = genes.round(decimals=5)
genes
# Out:
#             GeneID Chromosome       Start         End        GeneName  \
# 0      FBgn0038189         3R  13944654.0  13945812.0            Art6
# 1      FBgn0037583         3R   8359958.0   8362554.0          Veneno
# 2      FBgn0267702         3R  17703695.0  17705581.0  lncRNA:CR46035
# 3      FBgn0083949         3R   5862865.0   5959555.0        side-III
# 4      FBgn0038054         3R  12452464.0  12453196.0          CG5509
# ...            ...        ...         ...         ...             ...
# 10407  FBgn0036169        NaN         NaN         NaN             NaN
# 10408  FBgn0086037        NaN         NaN         NaN             NaN
# 10409  FBgn0086052        NaN         NaN         NaN             NaN
# 10410  FBgn0025687        NaN         NaN         NaN             NaN
# 10411  FBgn0267911        NaN         NaN         NaN             NaN
#
#       Immune Process Time_cluster   Length      FB_Gene  tpm_ctrl   tpm_20e  \
# 0                NaN          NaN   1158.0  FBgn0038189   0.00000   0.00000
# 1                NaN          NaN   2596.0  FBgn0037583  47.17868  47.39516
# 2                NaN          NaN   1886.0  FBgn0267702   1.19688   3.21491
# 3                NaN          NaN  96690.0  FBgn0083949   0.03985   0.05868
# 4                NaN          NaN    732.0  FBgn0038054   1.33923   1.78048
# ...              ...          ...      ...          ...       ...       ...
# 10407            NaN          NaN      NaN          NaN       NaN       NaN
# 10408            NaN          NaN      NaN  FBgn0086037   0.49338   0.00000
# 10409            NaN          NaN      NaN  FBgn0086052   0.00000   0.00000
# 10410            NaN          NaN      NaN          NaN       NaN       NaN
# 10411            NaN          NaN      NaN          NaN       NaN       NaN
#
#         tpm_imd
# 0       0.00000
# 1      30.42884
# 2       1.97773
# 3       0.03951
# 4       0.87884
# ...         ...
# 10407       NaN
# 10408   0.33462
# 10409   0.15685
# 10410       NaN
# 10411       NaN
#
# [10412 rows x 12 columns]

# %%
genes.drop('FB_Gene',axis=1).to_csv('processed_data/genes.csv', index = False)

# %% [markdown]
# ### flybase gtf

# %%
'''# Read gtf file
gtf_file = read_gtf('base_data/dmel-all-r6.64.gtf')
print(gtf_file.shape)
gtf_file.head()'''
# Out:
# "# Read gtf file\ngtf_file = read_gtf('base_data/dmel-all-r6.64.gtf')\nprint(gtf_file.shape)\ngtf_file.head()"

# %%
'''gtf_genes = gtf_file.filter(pl.col("feature") == "gene")
gtf_genes.head(n = 10)'''
# Out:
# 'gtf_genes = gtf_file.filter(pl.col("feature") == "gene")\ngtf_genes.head(n = 10)'

# %%
'''filtered_genes = gtf_genes.filter(pl.col("gene_id").is_in(unique_genes))'''
# Out:
# 'filtered_genes = gtf_genes.filter(pl.col("gene_id").is_in(unique_genes))'

# %%
'''result_df = pd.merge(
    filtered_genes[['gene_id','seqname','start','end','gene_symbol']].to_pandas(),
    gene_df[['gene_id','Immune Process', 'Time_cluster']],
    on='gene_id',
    how='left'
)
result_df.columns = ['GeneID','Chromosome', 'Start', 'End', 'GeneName','Immune Process','Time_cluster']
result_df.drop_duplicates(ignore_index = True,inplace = True)
result_df.reset_index(drop=True, inplace=True)
result_df
'''
# Out:
# "result_df = pd.merge(\n    filtered_genes[['gene_id','seqname','start','end','gene_symbol']].to_pandas(),\n    gene_df[['gene_id','Immune Process', 'Time_cluster']],\n    on='gene_id',\n    how='left'\n)\nresult_df.columns = ['GeneID','Chromosome', 'Start', 'End', 'GeneName','Immune Process','Time_cluster']\nresult_df.drop_duplicates(ignore_index = True,inplace = True)\nresult_df.reset_index(drop=True, inplace=True)\nresult_df\n"

# %%
'''result_df.to_csv('genes.csv', index = False)'''
# Out:
# "result_df.to_csv('genes.csv', index = False)"

# %%
'''# Convert unique genes list to a set
unique_genes_set = set(unique_genes)

# Convert filtered gene_ids (Polars) to a set
filtered_gene_ids_set = set(filtered_genes["gene_id"].to_list())

# Find unmapped genes
unmapped_genes = unique_genes_set - filtered_gene_ids_set

print(f"Number of unmapped genes: {len(unmapped_genes)}")
unmapped_genes

# Unmapped genes were 140 (ensembl had 129 unmapped genes)
Hence, ensembl is the better ref database here'''
# Out:
# '# Convert unique genes list to a set\nunique_genes_set = set(unique_genes)\n\n# Convert filtered gene_ids (Polars) to a set\nfiltered_gene_ids_set = set(filtered_genes["gene_id"].to_list())\n\n# Find unmapped genes\nunmapped_genes = unique_genes_set - filtered_gene_ids_set\n\nprint(f"Number of unmapped genes: {len(unmapped_genes)}")\nunmapped_genes\n\n# Unmapped genes were 140 (ensembl had 129 unmapped genes)\nHence, ensembl is the better ref database here'

# %% [markdown]
# # Associations Table

# %%
print(combined_df.columns)
print(all_df.columns)
# Out:
# Index(['Enhancer', 'Genes', 'Cells_20EvsCTRL.table.logFC',
#        'coSTARR LogFC 20EvsControl', 'Immune Process', 'Time_cluster',
#        'Treatment', 'Control_ave', '2021 LogFC IMDvsCTRL',
#        'coSTARR LogFC HKSMvs20E', 'Chromosome', 'Start', 'End', 'Length'],
#       dtype='object')
# Index(['Enhancer', 'Genes', '2021 LogFC IMDvsCTRL', 'coSTARR LogFC HKSMvs20E',
#        'Immune Process', 'Time_cluster', 'new_act_score', 'Length',
#        'FlybaseID Lem_function', 'Type_function', 'FlybaseID Lem_subtype',
#        'subtype', 'crp_3', 'EcR_usp_3', 'Eip74EF_3', 'gcm_3', 'Hnf4_3',
#        'kay_Jra_3', 'Rel_3', 'slp2_fork_3', 'SREBP_3', 'srp_SANGER_3', 'Trl_3',
#        'XBP1_3', 'xrp1_3', 'TBS_10-3', 'Treatment', 'FB_Gene', 'Control_ave',
#        'Cells_20EvsCTRL.table.logFC', 'coSTARR LogFC 20EvsControl',
#        'HKSM_ATAC', 'Con_ATAC', 'Accessibility', 'TF_counts'],
#       dtype='object')

# %%
combined_df.shape
# Out:
# (39130, 14)

# %%
print(combined_df['Treatment'].unique())
all_df['Treatment'].unique()
# Out:
# ['20E' 'Control' 'IMD']
# array(['IMD', 'Control', '20E'], dtype=object)

# %%
''' # FROM PREVIOUS CODE
# USED AS REFERENCE
asc_df = all_df[['Enhancer','Genes','2021 LogFC IMDvsCTRL','Cells_20EvsCTRL.table.logFC','coSTARR LogFC HKSMvs20E','coSTARR LogFC 20EvsControl', 'Origin','Activity_score']]'''

asc_df = pd.merge(
    combined_df[['Enhancer','Genes','coSTARR LogFC HKSMvs20E',
                 'coSTARR LogFC 20EvsControl','2021 LogFC IMDvsCTRL','Treatment']],
    all_df[['Enhancer', 'Treatment', 'new_act_score','Accessibility']],
    on=['Enhancer','Treatment'],
    how='left'
)

# %%
asc_df[[]].notna()

asc_df = asc_df.rename(columns={'Genes':'Gene'})

# Drop rows where ALL logFC & Gene are missing
asc_df = asc_df[~asc_df[['Gene',
                         'coSTARR LogFC HKSMvs20E',
                         '2021 LogFC IMDvsCTRL',
                         'coSTARR LogFC 20EvsControl']].isnull().all(axis=1)]

# %%
asc_df
# Out:
#                    Enhancer         Gene  coSTARR LogFC HKSMvs20E  \
# 0      2R:16125955-16128021  FBgn0034075                      NaN
# 1      2R:16125955-16128021  FBgn0034076                      NaN
# 2      2R:16125955-16128021  FBgn0010052                      NaN
# 3      2R:16125955-16128021  FBgn0050095                      NaN
# 4      2R:16125955-16128021  FBgn0001124                      NaN
# ...                     ...          ...                      ...
# 39102         Y:14211-14771  FBgn0267433                      NaN
# 39104         Y:16815-17445  FBgn0267433                      NaN
# 39116       Y:283890-284788  FBgn0267449                      NaN
# 39125         Y:49440-50073  FBgn0267432                      NaN
# 39126         Y:62528-63265  FBgn0001313                      NaN
#
#        coSTARR LogFC 20EvsControl  2021 LogFC IMDvsCTRL Treatment  \
# 0                       -0.065139                   NaN       20E
# 1                             NaN                   NaN       20E
# 2                       -3.331694                   NaN       20E
# 3                             NaN                   NaN       20E
# 4                       -0.816459                   NaN       20E
# ...                           ...                   ...       ...
# 39102                         NaN              1.133805       IMD
# 39104                         NaN              1.133805       IMD
# 39116                         NaN                   NaN       IMD
# 39125                         NaN                   NaN       IMD
# 39126                         NaN                   NaN       IMD
#
#        new_act_score  Accessibility
# 0            1344.89    Always open
# 1            1344.89    Always open
# 2            1344.89    Always open
# 3            1344.89    Always open
# 4            1344.89    Always open
# ...              ...            ...
# 39102        1424.51  Always closed
# 39104        1062.99  Always closed
# 39116        1250.94  Always closed
# 39125        1134.60  Always closed
# 39126        1901.23  Always closed
#
# [37255 rows x 8 columns]

# %%
asc_df = asc_df.drop_duplicates().reset_index(drop=True)
asc_df = asc_df.round(5)

asc_df.to_csv('processed_data/associations.csv', index=False)

# %%
asc_df.columns
# Out:
# Index(['Enhancer', 'Gene', 'coSTARR LogFC HKSMvs20E',
#        'coSTARR LogFC 20EvsControl', '2021 LogFC IMDvsCTRL', 'Treatment',
#        'new_act_score', 'Accessibility'],
#       dtype='object')

# %% [markdown]
# # Tab 3 data

# %%
association_df = pd.read_csv('base_data/EG_activity_class_modified.csv')

# %%
association_df.drop(columns=['Unnamed: 7', 'Unnamed: 8'], inplace=True)
association_df.columns
# Out:
# Index(['Enhancer', 'Activity class', 'Accessibility', 'Gene',
#        'Distance to enhancer', 'Time Cluster', 'Broad Immune Role'],
#       dtype='object')

# %%
association_df.nunique()
# Out:
# Enhancer                4270
# Activity class             7
# Accessibility              4
# Gene                    4640
# Distance to enhancer    6381
# Time Cluster               4
# Broad Immune Role          7
# dtype: int64

# %%
for col in association_df.columns:
    l = association_df[col].unique()
    if len(l) < 50:
        print(col, l)
# Out:
# Activity class ['Control' '20E' 'HKSM' 'Control + 20E' 'Control + HKSM' 'HKSM + 20E'
#  'Constitutive']
# Accessibility ['Always open' 'Always closed' 'HKSM closed' 'HKSM opened']
# Time Cluster [nan 'Early' 'Mid' 'Late' 'Midlate']
# Broad Immune Role [nan 'Signaling' 'Recognition' 'Other' 'Effector' 'Effector (AMP)'
#  'Anti-viral' 'Effector (ROS)']

# %%
association_df.value_counts(subset=['Enhancer','Gene'],ascending=False)
# Out:
# Enhancer              Gene
# 2L:10056850-10057876  FBgn0032178    1
# 3R:21662327-21662909  FBgn0011766    1
#                       FBgn0259113    1
# 3R:2168891-2169514    .              1
# 3R:21731337-21731939  FBgn0038897    1
#                                     ..
# 2R:7457211-7458216    FBgn0033178    1
# 2R:7492719-7493388    FBgn0015929    1
#                       FBgn0033183    1
#                       FBgn0259745    1
# Y:922754-923487       .              1
# Name: count, Length: 9692, dtype: int64

# %%
association_df.to_csv('processed_data/tab3_data.csv', index=False)
